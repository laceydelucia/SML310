# %%
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"
import warnings
warnings.filterwarnings("ignore")

import pandas as pd
import datetime
import numpy as np
from matplotlib import pyplot as plt
import plotly.express as px
from plotly.offline import init_notebook_mode, iplot
init_notebook_mode(connected=True)
from statsmodels.tsa.seasonal import seasonal_decompose
from statsmodels.tsa.stattools import adfuller
from statsmodels.tsa.stattools import grangercausalitytests
from statsmodels.graphics.tsaplots import plot_acf, plot_pacf
from statsmodels.tsa.arima.model import ARIMA
from sklearn.metrics import mean_squared_error
from sklearn.preprocessing import MinMaxScaler
from math import sqrt
from sklearn.metrics import mean_absolute_error as mae 
import tensorflow as tf
from tensorflow.keras.models import Sequential
from keras.layers import Dense
from keras.layers import LSTM
from keras.layers import Dropout
from keras.callbacks import EarlyStopping

np.random.seed(234)
tf.random.set_seed(234)
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.12.1.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>
# 2024-04-22 17:08:34.291670: I tensorflow/core/util/port.cc:113] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2024-04-22 17:08:34.334158: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F AVX512_VNNI AVX512_BF16 AVX512_FP16 AVX_VNNI AMX_TILE AMX_INT8 AMX_BF16 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2024-04-22 17:08:35.215350: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %%
##https://machinelearningmastery.com/multivariate-time-series-forecasting-lstms-keras/
##https://www.kaggle.com/code/calven22/forecasting-inflation-with-arima-and-lstm

# %%
dataset = pd.read_csv('InflationData.csv')

# %%
date = pd.date_range('1/1/1959', periods=len(data), freq='m')
values = dataset.values
data = dataset.loc[:, dataset.columns != 'DATE']
data
# Out:
#          OIL  PersonalExpenditure  RealDisposableIncome  M2REAL  Unemployment  \
# 0     13.900                306.1                2318.4   987.9           6.0
# 1     13.900                309.6                2325.4   992.1           5.9
# 2     14.000                312.7                2338.7   998.3           5.6
# 3     14.000                312.2                2353.8  1001.0           5.2
# 4     14.000                316.1                2366.6  1006.2           5.1
# ..       ...                  ...                   ...     ...           ...
# 777  396.278              18826.8               16847.8  6730.6           3.8
# 778  392.414              18903.0               16912.1  6728.3           3.7
# 779  382.583              19013.7               16946.5  6732.5           3.7
# 780  373.663              19043.6               16946.7  6713.3           3.7
# 781  376.162              19189.0               16931.6  6681.7           3.9
#
#      InterestRate  FoodIndex
# 0            2.48     29.800
# 1            2.43     29.700
# 2            2.80     29.500
# 3            2.96     29.500
# 4            2.90     29.500
# ..            ...        ...
# 777          5.33    325.731
# 778          5.33    325.172
# 779          5.33    325.409
# 780          5.33    327.327
# 781          5.33    327.731
#
# [782 rows x 7 columns]

# %%
plt.title("Oil Prices")
plt.plot(date, data['OIL'])
# Out:
# Text(0.5, 1.0, 'Oil Prices')

# %%
plt.title("Personal Expenditure")
plt.plot(date, data['PersonalExpenditure'])
# Out:
# Text(0.5, 1.0, 'Personal Expenditure')

# %%
plt.title("Disposable Income")
plt.plot(date, data['RealDisposableIncome'])
# Out:
# Text(0.5, 1.0, 'Disposable Income')

# %%
plt.title("M2")
plt.plot(date, data['M2REAL'])
# Out:
# Text(0.5, 1.0, 'M2')

# %%
plt.title("Interest Rate")
plt.plot(date, data['InterestRate'])
# Out:
# Text(0.5, 1.0, 'Interest Rate')

# %%
plt.title("Unemployment Rate")
plt.plot(date, data['Unemployment'])
# Out:
# Text(0.5, 1.0, 'Unemployment Rate')

# %%
plt.title("Food Index")
plt.plot(date, data['FoodIndex'])
# Out:
# Text(0.5, 1.0, 'Food Index')

# %%
data = data.drop(columns=['OIL','RealDisposableIncome','M2REAL','PersonalExpenditure'])
data
# Out:
#      Unemployment  InterestRate  FoodIndex
# 0             6.0          2.48     29.800
# 1             5.9          2.43     29.700
# 2             5.6          2.80     29.500
# 3             5.2          2.96     29.500
# 4             5.1          2.90     29.500
# ..            ...           ...        ...
# 777           3.8          5.33    325.731
# 778           3.7          5.33    325.172
# 779           3.7          5.33    325.409
# 780           3.7          5.33    327.327
# 781           3.9          5.33    327.731
#
# [782 rows x 3 columns]

# %%
from math import sqrt
from numpy import concatenate
from matplotlib import pyplot
from pandas import read_csv
from pandas import DataFrame
from pandas import concat
from sklearn.preprocessing import MinMaxScaler
from sklearn.preprocessing import LabelEncoder
from sklearn.metrics import mean_squared_error
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import LSTM
 
# convert series to supervised learning
def series_to_supervised(data, n_in=1, n_out=1, dropnan=True):
	n_vars = 1 if type(data) is list else data.shape[1]
	df = DataFrame(data)
	cols, names = list(), list()
	# input sequence (t-n, ... t-1)
	for i in range(n_in, 0, -1):
		cols.append(df.shift(i))
		names += [('var%d(t-%d)' % (j+1, i)) for j in range(n_vars)]
	# forecast sequence (t, t+1, ... t+n)
	for i in range(0, n_out):
		cols.append(df.shift(-i))
		if i == 0:
			names += [('var%d(t)' % (j+1)) for j in range(n_vars)]
		else:
			names += [('var%d(t+%d)' % (j+1, i)) for j in range(n_vars)]
	# put it all together
	agg = concat(cols, axis=1)
	agg.columns = names
	# drop rows with NaN values
	if dropnan:
		agg.dropna(inplace=True)
	return agg
 


# normalize features
scaler = MinMaxScaler(feature_range=(0, 1))
scaled = scaler.fit_transform(data)
# frame as supervised learning


reframed = series_to_supervised(scaled, 1, 1)
reframed
# Out:
#      var1(t-1)  var2(t-1)  var3(t-1)   var1(t)   var2(t)   var3(t)
# 1     0.228070   0.127559   0.001341  0.219298  0.124934  0.001006
# 2     0.219298   0.124934   0.001006  0.192982  0.144357  0.000335
# 3     0.192982   0.144357   0.000335  0.157895  0.152756  0.000335
# 4     0.157895   0.152756   0.000335  0.149123  0.149606  0.000335
# 5     0.149123   0.149606   0.000335  0.140351  0.175328  0.001341
# ..         ...        ...        ...       ...       ...       ...
# 777   0.035088   0.277165   0.989854  0.035088  0.277165  0.993296
# 778   0.035088   0.277165   0.993296  0.026316  0.277165  0.991422
# 779   0.026316   0.277165   0.991422  0.026316  0.277165  0.992217
# 780   0.026316   0.277165   0.992217  0.026316  0.277165  0.998646
# 781   0.026316   0.277165   0.998646  0.043860  0.277165  1.000000
#
# [781 rows x 6 columns]

# %%
reframed.drop(reframed.columns[[3,4]], axis=1, inplace=True)
reframed.head()
# Out:
#    var1(t-1)  var2(t-1)  var3(t-1)   var3(t)
# 1   0.228070   0.127559   0.001341  0.001006
# 2   0.219298   0.124934   0.001006  0.000335
# 3   0.192982   0.144357   0.000335  0.000335
# 4   0.157895   0.152756   0.000335  0.000335
# 5   0.149123   0.149606   0.000335  0.001341

# %%
# 80 - 20 split
n_train_hours = int(len(values) *0.8)
print(len(values)-n_train_hours)
# Out:
# 157

# %%
# split into train and test sets
values = reframed.values
n_train_hours = int(len(values) *0.8)

train = values[:n_train_hours, :]
test = values[n_train_hours:, :]
# split into input and outputs
train_X, train_y = train[:, :-1], train[:, -1]
test_X, test_y = test[:, :-1], test[:, -1]
# reshape input to be 3D [samples, timesteps, features]
train_X = train_X.reshape((train_X.shape[0], 1, train_X.shape[1]))
test_X = test_X.reshape((test_X.shape[0], 1, test_X.shape[1]))
print(train_X.shape, train_y.shape, test_X.shape, test_y.shape)
# Out:
# (624, 1, 3) (624,) (157, 1, 3) (157,)

# %%
# design network
model = Sequential()
model.add(LSTM(100, input_shape=(train_X.shape[1], train_X.shape[2])))
model.add(Dropout(0.2))
model.add(Dense(1))
model.compile(loss='mae', optimizer='adam')

# %%
history = model.fit(train_X, train_y, epochs=70, batch_size=72, validation_data=(test_X, test_y), verbose=2, shuffle=False)
# plot history
pyplot.plot(history.history['loss'], label='train')
pyplot.plot(history.history['val_loss'], label='test')
pyplot.legend()
pyplot.show()
# Out:
# Epoch 1/70
# 9/9 - 1s - 144ms/step - loss: 0.2279 - val_loss: 0.7214
# Epoch 2/70
# 9/9 - 0s - 6ms/step - loss: 0.1973 - val_loss: 0.6666
# Epoch 3/70
# 9/9 - 0s - 6ms/step - loss: 0.1764 - val_loss: 0.6169
# Epoch 4/70
# 9/9 - 0s - 6ms/step - loss: 0.1645 - val_loss: 0.5739
# Epoch 5/70
# 9/9 - 0s - 6ms/step - loss: 0.1573 - val_loss: 0.5371
# Epoch 6/70
# 9/9 - 0s - 6ms/step - loss: 0.1515 - val_loss: 0.5045
# Epoch 7/70
# 9/9 - 0s - 6ms/step - loss: 0.1462 - val_loss: 0.4740
# Epoch 8/70
# 9/9 - 0s - 6ms/step - loss: 0.1393 - val_loss: 0.4451
# Epoch 9/70
# 9/9 - 0s - 6ms/step - loss: 0.1337 - val_loss: 0.4178
# Epoch 10/70
# 9/9 - 0s - 6ms/step - loss: 0.1275 - val_loss: 0.3903
# Epoch 11/70
# 9/9 - 0s - 6ms/step - loss: 0.1218 - val_loss: 0.3630
# Epoch 12/70
# 9/9 - 0s - 6ms/step - loss: 0.1145 - val_loss: 0.3353
# Epoch 13/70
# 9/9 - 0s - 6ms/step - loss: 0.1077 - val_loss: 0.3070
# Epoch 14/70
# 9/9 - 0s - 6ms/step - loss: 0.0998 - val_loss: 0.2793
# Epoch 15/70
# 9/9 - 0s - 6ms/step - loss: 0.0933 - val_loss: 0.2512
# Epoch 16/70
# 9/9 - 0s - 6ms/step - loss: 0.0849 - val_loss: 0.2224
# Epoch 17/70
# 9/9 - 0s - 7ms/step - loss: 0.0769 - val_loss: 0.1926
# Epoch 18/70
# 9/9 - 0s - 6ms/step - loss: 0.0674 - val_loss: 0.1614
# Epoch 19/70
# 9/9 - 0s - 6ms/step - loss: 0.0591 - val_loss: 0.1297
# Epoch 20/70
# 9/9 - 0s - 6ms/step - loss: 0.0515 - val_loss: 0.0985
# Epoch 21/70
# 9/9 - 0s - 6ms/step - loss: 0.0450 - val_loss: 0.0710
# Epoch 22/70
# 9/9 - 0s - 6ms/step - loss: 0.0387 - val_loss: 0.0490
# Epoch 23/70
# 9/9 - 0s - 6ms/step - loss: 0.0356 - val_loss: 0.0341
# Epoch 24/70
# 9/9 - 0s - 6ms/step - loss: 0.0325 - val_loss: 0.0220
# Epoch 25/70
# 9/9 - 0s - 6ms/step - loss: 0.0311 - val_loss: 0.0154
# Epoch 26/70
# 9/9 - 0s - 6ms/step - loss: 0.0293 - val_loss: 0.0111
# Epoch 27/70
# 9/9 - 0s - 6ms/step - loss: 0.0270 - val_loss: 0.0080
# Epoch 28/70
# 9/9 - 0s - 6ms/step - loss: 0.0241 - val_loss: 0.0116
# Epoch 29/70
# 9/9 - 0s - 6ms/step - loss: 0.0229 - val_loss: 0.0125
# Epoch 30/70
# 9/9 - 0s - 6ms/step - loss: 0.0225 - val_loss: 0.0157
# Epoch 31/70
# 9/9 - 0s - 6ms/step - loss: 0.0203 - val_loss: 0.0148
# Epoch 32/70
# 9/9 - 0s - 6ms/step - loss: 0.0190 - val_loss: 0.0151
# Epoch 33/70
# 9/9 - 0s - 6ms/step - loss: 0.0166 - val_loss: 0.0166
# Epoch 34/70
# 9/9 - 0s - 6ms/step - loss: 0.0161 - val_loss: 0.0157
# Epoch 35/70
# 9/9 - 0s - 6ms/step - loss: 0.0156 - val_loss: 0.0214
# Epoch 36/70
# 9/9 - 0s - 6ms/step - loss: 0.0141 - val_loss: 0.0183
# Epoch 37/70
# 9/9 - 0s - 6ms/step - loss: 0.0146 - val_loss: 0.0165
# Epoch 38/70
# 9/9 - 0s - 6ms/step - loss: 0.0167 - val_loss: 0.0183
# Epoch 39/70
# 9/9 - 0s - 6ms/step - loss: 0.0150 - val_loss: 0.0139
# Epoch 40/70
# 9/9 - 0s - 6ms/step - loss: 0.0152 - val_loss: 0.0238
# Epoch 41/70
# 9/9 - 0s - 6ms/step - loss: 0.0155 - val_loss: 0.0144
# Epoch 42/70
# 9/9 - 0s - 6ms/step - loss: 0.0149 - val_loss: 0.0232
# Epoch 43/70
# 9/9 - 0s - 6ms/step - loss: 0.0153 - val_loss: 0.0125
# Epoch 44/70
# 9/9 - 0s - 6ms/step - loss: 0.0145 - val_loss: 0.0234
# Epoch 45/70
# 9/9 - 0s - 6ms/step - loss: 0.0144 - val_loss: 0.0141
# Epoch 46/70
# 9/9 - 0s - 6ms/step - loss: 0.0139 - val_loss: 0.0256
# Epoch 47/70
# 9/9 - 0s - 6ms/step - loss: 0.0152 - val_loss: 0.0124
# Epoch 48/70
# 9/9 - 0s - 6ms/step - loss: 0.0162 - val_loss: 0.0232
# Epoch 49/70
# 9/9 - 0s - 6ms/step - loss: 0.0158 - val_loss: 0.0125
# Epoch 50/70
# 9/9 - 0s - 6ms/step - loss: 0.0153 - val_loss: 0.0220
# Epoch 51/70
# 9/9 - 0s - 6ms/step - loss: 0.0152 - val_loss: 0.0124
# Epoch 52/70
# 9/9 - 0s - 6ms/step - loss: 0.0156 - val_loss: 0.0214
# Epoch 53/70
# 9/9 - 0s - 6ms/step - loss: 0.0152 - val_loss: 0.0118
# Epoch 54/70
# 9/9 - 0s - 6ms/step - loss: 0.0137 - val_loss: 0.0216
# Epoch 55/70
# 9/9 - 0s - 6ms/step - loss: 0.0141 - val_loss: 0.0187
# Epoch 56/70
# 9/9 - 0s - 6ms/step - loss: 0.0141 - val_loss: 0.0168
# Epoch 57/70
# 9/9 - 0s - 6ms/step - loss: 0.0142 - val_loss: 0.0167
# Epoch 58/70
# 9/9 - 0s - 6ms/step - loss: 0.0133 - val_loss: 0.0124
# Epoch 59/70
# 9/9 - 0s - 6ms/step - loss: 0.0138 - val_loss: 0.0158
# Epoch 60/70
# 9/9 - 0s - 6ms/step - loss: 0.0144 - val_loss: 0.0157
# Epoch 61/70
# 9/9 - 0s - 6ms/step - loss: 0.0132 - val_loss: 0.0145
# Epoch 62/70
# 9/9 - 0s - 6ms/step - loss: 0.0145 - val_loss: 0.0129
# Epoch 63/70
# 9/9 - 0s - 6ms/step - loss: 0.0139 - val_loss: 0.0131
# Epoch 64/70
# 9/9 - 0s - 6ms/step - loss: 0.0139 - val_loss: 0.0222
# Epoch 65/70
# 9/9 - 0s - 6ms/step - loss: 0.0132 - val_loss: 0.0146
# Epoch 66/70
# 9/9 - 0s - 6ms/step - loss: 0.0131 - val_loss: 0.0177
# Epoch 67/70
# 9/9 - 0s - 6ms/step - loss: 0.0131 - val_loss: 0.0183
# Epoch 68/70
# 9/9 - 0s - 6ms/step - loss: 0.0137 - val_loss: 0.0158
# Epoch 69/70
# 9/9 - 0s - 6ms/step - loss: 0.0136 - val_loss: 0.0181
# Epoch 70/70
# 9/9 - 0s - 6ms/step - loss: 0.0136 - val_loss: 0.0129

# %%
n_features=3
def feature_importance(model, g):
    random_ind = np.random.choice(g.shape[0], 100, replace=False) # Randomly generate 100 numbers arange(218) 
    x = g[random_ind] #  Take 100 random sample from training set
    orig_out = model.predict(x)
    for i in range(n_features):  # iterate over the 7 features
        new_x = x.copy()
        perturbation_in = np.random.normal(0.0, 0.7, size=new_x.shape[:2]) # Draw random samples from normal distribution with sd = 0.7, this value is arbitary and would not affect the order of effect as its just introducing noise.
        new_x[:, :, i] = new_x[:, :, i] + perturbation_in
        perturbed_out = model.predict(new_x)
        effect = ((orig_out - perturbed_out) ** 2).mean() ** 0.5
        print(f'Variable {i+1}, Perturbation Effect: {effect:.3f}')
        
feature_importance(model,train_X)
# Out:
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 907us/step
# Variable 1, Perturbation Effect: 0.013
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 774us/step
# Variable 2, Perturbation Effect: 0.022
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 881us/step
# Variable 3, Perturbation Effect: 0.678

# %%
# calculate RMSE
yhat = model.predict(test_X)
rmse = sqrt(mean_squared_error(test_y, yhat))
print('Test RMSE: %.3f' % rmse)
error = mae(test_y, yhat) 
  
# display 
print("Mean absolute error : " + str(error))
# Out:
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 796us/step
# Test RMSE: 0.011
# Mean absolute error : 0.0055799711946358235

# %%
test_X = test_X.reshape((test_X.shape[0], test_X.shape[2]))
# invert scaling for forecast

# %%
data.shape
inv_yhat = concatenate((test_X[:, 0:2],yhat), axis=1)
inv_yhat = scaler.inverse_transform(inv_yhat)


# invert caling for actual
test_y = test_y.reshape((len(test_y), 1))
inv_y = concatenate((test_X[:, 0:2],test_y), axis=1)
inv_y = scaler.inverse_transform(inv_y)
inv_y = inv_y[:, -1:]
inv_yhat = inv_yhat[:, -1:]
# Out:
# (782, 3)

# %%
# calculate RMSE
rmse = sqrt(mean_squared_error(inv_y, inv_yhat))
print('Test RMSE: %.3f' % rmse)
error = mae(inv_y, inv_yhat) 
  
# display 
print("Mean absolute error : " + str(error))
# Out:
# Test RMSE: 3.162
# Mean absolute error : 1.6646783864668953

# %%
startDate = int(len(values) *0.8)+1
dates = dataset['DATE'][startDate:]
dates
# Out:
# 625     2/1/11
# 626     3/1/11
# 627     4/1/11
# 628     5/1/11
# 629     6/1/11
#         ...
# 777    10/1/23
# 778    11/1/23
# 779    12/1/23
# 780     1/1/24
# 781     2/1/24
# Name: DATE, Length: 157, dtype: object

# %%
date = pd.date_range('2/1/2011', periods=len(dates), freq='m')

# %%
plt.plot(date, inv_y, color ='red')
plt.plot(date, inv_yhat)
plt.title("True vs Predicted Food Inflation (Food Index t-1)")
plt.xlabel("Dates")
plt.ylabel("Food Index")
plt.xticks(rotation='vertical')
# Out:
# Text(0.5, 1.0, 'True vs Predicted Food Inflation (Food Index t-1)')
# Text(0.5, 0, 'Dates')
# Text(0, 0.5, 'Food Index')
# (array([14610., 15340., 16071., 16801., 17532., 18262., 18993., 19723.]),
#  [Text(14610.0, 0, '2010'),
#   Text(15340.0, 0, '2012'),
#   Text(16071.0, 0, '2014'),
#   Text(16801.0, 0, '2016'),
#   Text(17532.0, 0, '2018'),
#   Text(18262.0, 0, '2020'),
#   Text(18993.0, 0, '2022'),
#   Text(19723.0, 0, '2024')])

# %%
df = pd.DataFrame()
df['date'] = dates
df['inv_y'] = inv_y
df['inv_yhat'] = inv_yhat
df.to_csv("FoodInflationPred_FI_IR_UE.csv")
model.save("InflationLSTM_FI_IR_UE.keras")
